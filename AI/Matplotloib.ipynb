# %%
import matplotlib.pyplot as plt

x = list (range(0, 10))
y = list (range(-10, 0))

plt.plot(x, y)

# %%
a = [0, -100, 25, 67, -323]
b = [0, 3, 7, 3, 9]
plt.plot(a,b)

# %%
plt.axis([-50, 80, 2, 8])
plt.plot(a, b)

# %%
plt.title("triangle")
plt.xlabel("Array A")
plt.ylabel("Array B")
plt.axis([-50, 80, 2, 8])
plt.xticks((-40, -20, 0, 20, 40), ('h', 'e', 'l', 'l', 'o'))
plt.plot(a, b, color='red')

# %%
plt.hist(a)
plt.hist(b)
# Out:
# (array([1., 0., 0., 2., 0., 0., 0., 1., 0., 1.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)
